# %% [markdown]
# <a href="https://colab.research.google.com/github/Ragnarok540/sympy-tutorial/blob/main/eigenstate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://www.youtube.com/watch?v=ay0zZ8SUMSk

import numpy as np
import matplotlib.pyplot as plt
from scipy.linalg import eigh_tridiagonal

# %%
n = 100
dy = 1 / n
y = np.linspace(0, 1, n + 1)

def mL2V(y):
    return 1000 * np.sin(20 * y) * y**4

# %%
plt.figure(figsize=(10,5))
plt.plot(y, mL2V(y))
plt.title('Potential', fontsize=30)
plt.ylabel('$V/V_0$', fontsize=25)
plt.xlabel('$x/L$', fontsize=25)
plt.grid()

# %%
d = 1 / dy**2 + mL2V(y)[1:-1]
e = -1 / (2 * dy**2) * np.ones(len(d) - 1)

w, v = eigh_tridiagonal(d, e)

# %%
plt.figure(figsize=(10,5))
plt.plot(y[1:-1], v.T[0])
plt.plot(y[1:-1], v.T[1])
plt.plot(y[1:-1], v.T[2])
plt.plot(y[1:-1], v.T[3])
plt.title('Eigenstates', fontsize=30)
plt.ylabel('$\psi$', fontsize=25)
plt.xlabel('$x/L$', fontsize=25)
plt.grid()

# %%
plt.bar(np.arange(0, 10, 1), w[0:10])
plt.ylabel('$mL^2 E/\hbar^2$')
# Out:
# Text(0, 0.5, '$mL^2 E/\\hbar^2$')
